# %%
import pawn.pawn_game_solver as pgs
import logging
import cProfile
import pstats
from pstats import SortKey

# %%
fen = pgs.pawn_game_fen(4)
solver = pgs.PawnGameSolver(max_depth_print=-1)

# %%
cProfile.run('result = solver.search(fen)[0]', 'stats')

# %%
p = pstats.Stats('stats')
p.sort_stats(SortKey.CUMULATIVE).print_stats(20)
# Out:
# Sun Jul  4 10:17:56 2021    stats
#
#          22600303 function calls (22436080 primitive calls) in 12.159 seconds
#
#    Ordered by: cumulative time
#    List reduced from 92 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   12.159   12.159 {built-in method builtins.exec}
#         1    0.000    0.000   12.159   12.159 <string>:1(<module>)
#         1    0.000    0.000   12.159   12.159 /Users/olivne/oren/zz/pawn/pawn_game_solver.py:78(search)
#  164224/1    0.759    0.000   12.159   12.159 /Users/olivne/oren/zz/pawn/pawn_game_solver.py:88(_search)
#    120716    0.087    0.000    6.504    0.000 /Users/olivne/oren/zz/pawn/pawn_game_solver.py:205(_evaluate)
#    120716    0.116    0.000    4.776    0.000 /Users/olivne/oren/zz/pawn/delegating_pawn_board.py:52(evaluate)
#    120716    0.282    0.000    4.181    0.000 /Users/olivne/oren/zz/pawn/delegating_pawn_board.py:62(evaluate)
#    842147    0.377    0.000    2.929    0.000 /Users/olivne/opt/miniconda3/envs/zz/lib/python3.7/site-packages/chess/__init__.py:3240(generate_legal_moves)
#    176741    0.160    0.000    2.717    0.000 /Users/olivne/oren/zz/pawn/delegating_pawn_board.py:97(min_steps_to_promotion)
#    164223    0.078    0.000    2.697    0.000 /Users/olivne/oren/zz/pawn/delegating_pawn_board.py:40(push)
#    842147    1.647    0.000    2.619    0.000 /Users/olivne/opt/miniconda3/envs/zz/lib/python3.7/site-packages/chess/__init__.py:1455(generate_pseudo_legal_moves)
#    164223    0.954    0.000    2.619    0.000 /Users/olivne/opt/miniconda3/envs/zz/lib/python3.7/site-packages/chess/__init__.py:1924(push)
#    176741    0.211    0.000    2.558    0.000 /Users/olivne/oren/zz/pawn/delegating_pawn_board.py:104(_min_steps_to_promotion)
#    195967    0.334    0.000    2.309    0.000 {built-in method builtins.min}
#    716971    0.358    0.000    1.913    0.000 /Users/olivne/oren/zz/pawn/delegating_pawn_board.py:106(<genexpr>)
#     90244    0.073    0.000    1.641    0.000 /Users/olivne/oren/zz/pawn/delegating_pawn_board.py:37(has_legal_moves)
#     90244    0.164    0.000    1.506    0.000 /Users/olivne/opt/miniconda3/envs/zz/lib/python3.7/site-packages/chess/__init__.py:3468(count)
#    540230    0.236    0.000    1.219    0.000 /Users/olivne/oren/zz/pawn/delegating_pawn_board.py:112(_num_steps_to_promotion)
#    131167    0.082    0.000    1.036    0.000 {built-in method builtins.any}
#    540230    0.314    0.000    0.983    0.000 /Users/olivne/oren/zz/pawn/delegating_pawn_board.py:159(_is_path_clear)

# %%
len(solver.memo)
# Out:
# 112400
